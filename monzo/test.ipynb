# %%
import requests
import json

# %%
account_id = "acc_00009Z2tvgLIZFhEkyu1uj"

# %%
req

# %%
auth_token="eyJhbGciOiJFUzI1NiIsInR5cCI6IkpXVCJ9.eyJlYiI6IjF0Vjc2V1RhNi9MNWI3RVRTMnNwIiwianRpIjoiYWNjdG9rXzAwMDA5b2EzN2FJT3NkMDNBZ3FseXoiLCJ0eXAiOiJhdCIsInYiOiI2In0.1vhzzOaN4WWhfdzT8of62kNsel-rraX1kK5y0_ndIT_ZifnC1H1V0Lt34c4byZmGvNiezdOzlZdQ9t2AaYEaXQ"


r = requests.get("https://api.monzo.com/balance",
                 params={'account_id': 'acc_00009Z2tvgLIZFhEkyu1uj'},
                 headers={'Authorization': "Bearer %s" %auth_token})

# %%
r.content
# Out:
# b'{"balance":17025,"total_balance":17669,"balance_including_flexible_savings":17669,"currency":"GBP","spend_today":0,"local_currency":"SEK","local_exchange_rate":12.371866,"local_spend":[]}\n'

# %%
auth_token="eyJhbGciOiJFUzI1NiIsInR5cCI6IkpXVCJ9.eyJlYiI6IlFXUi93TER6QlVYZGs2Vk5iNTZ3IiwianRpIjoiYWNjdG9rXzAwMDA5b2E3bU81bFlla0wyTldlM3QiLCJ0eXAiOiJhdCIsInYiOiI2In0.nd2c5dnhCOrWgPMOycHsWMaIaHnpq6DUpmvo9QJ6fCTjPjrytKT8v09PripFNZFtBXTwHlRTxcdRUZ3Do-sgeA"


r = requests.get("https://api.monzo.com/transactions",
                 params={'account_id': 'acc_00009Z2tvgLIZFhEkyu1uj'},
                 headers={'Authorization': "Bearer %s" %auth_token})

# %%
json_obj=json.loads(r.content)

# %%
json_obj
# Out:
# {'transactions': [{'account_balance': 0,
#    'account_id': 'acc_00009Z2tvgLIZFhEkyu1uj',
#    'amount': 25000,
#    'amount_is_pending': False,
#    'attachments': [],
#    'can_add_to_tab': False,
#    'can_be_excluded_from_breakdown': False,
#    'can_be_made_subscription': False,
#    'can_split_the_bill': False,
#    'category': 'general',
#    'counterparty': {'account_number': '69261601',
#     'name': 'THOMAS RR',
#     'sort_code': '516102',
#     'user_id': 'anonuser_d75895ea98276a1cfbccce'},
#    'created': '2018-09-01T15:15:28.106Z',
#    'currency': 'GBP',
#    'dedupe_id': 'com.monzo.fps:9200:62161527917362000N1020180901826516102:INBOUND',
#    'description': 'RT',
#    'fees': {},
#    'id': 'tx_00009aHOk1PCIHR57cDWAz',
#    'include_in_spending': False,
#    'international': None,
#    'is_load': False,
#    'labels': None,
#    'local_amount': 25000,
#    'local_currency': 'GBP',
#    'merchant': None,
#    'metadata': {'faster_payment': 'true',
# ...

# %%
amounts = []
for i in json_obj['transactions']:
    amounts.append(i['amount'])

# %%
places = []
for i in json_obj['transactions']:
    places.append(i['description'])

# %%
from nltk.tokenize import word_tokenize

# %%
def split_up(place):
    tokens = [i for i in place]
    country = ''.join(tokens[-3:])
    tokens = ''.join(tokens[:-3])
    #print(''.join(country))
    
    town = word_tokenize(tokens)[-1]
    place = ' '.join(word_tokenize(tokens)[:-1])
    if type(town) == str:
        town = town
    else:
        town = None
    return place, town, country

# %%
places_spent_money = set(places)
them_places = {}
for i in places_spent_money:
    if len(i) == 2:
        continue
    else:
        place, town, country = split_up(i)
        them_places[place] = place
        them_places[town] = town
        them_places[country] = country
    
    
them_places

# %%
places[24]

# %%
from random_string import randomString

# %%
s = randomString()

# %%
# Out:
# 'zauedjkwvm'

# %%
r = requests.get("https://api.monzo.com/pots/pot_00009cj4TafFU2lqI95qR0/deposit",
                 params={'ammount'           : 200,
                         'source_account_id' : "user_00009Z2sSGIUDzcXctzkcD!",
                         'dedupe_id'         : s},
                 headers={'Authorization'    : "Bearer %s" %auth_token})

# %%
json_obj=json.loads(r.content)

# %%
json_obj
# Out:
# {'code': 'not_found.no_handler',
#  'message': 'No handler for GET /pot_00009cj4TafFU2lqI95qR0/deposit'}

# %%
HEADERS = {"Authorization" : "Bearer eyJhbGciOiJFUzI1NiIsInR5cCI6IkpXVCJ9.eyJlYiI6IlFXUi93TER6QlVYZGs2Vk5iNTZ3IiwianRpIjoiYWNjdG9rXzAwMDA5b2E3bU81bFlla0wyTldlM3QiLCJ0eXAiOiJhdCIsInYiOiI2In0.nd2c5dnhCOrWgPMOycHsWMaIaHnpq6DUpmvo9QJ6fCTjPjrytKT8v09PripFNZFtBXTwHlRTxcdRUZ3Do-sgeA"}
ACCOUNT_ID = "user_00009Z2sSGIUDzcXctzkcD"
ACCOUNTS = "https://api.monzo.com/accounts"

# %%
r = requests.get(ACCOUNTS, headers=HEADERS)

# %%
response = requests.get(ACCOUNTS, headers=HEADERS).json()

# %%
response
# Out:
# {'accounts': [{'account_number': '16117989',
#    'closed': False,
#    'country_code': 'GB',
#    'created': '2018-07-26T17:32:09.827Z',
#    'currency': 'GBP',
#    'description': 'user_00009Z2sSGIUDzcXctzkcD',
#    'id': 'acc_00009Z2tvgLIZFhEkyu1uj',
#    'owners': [{'preferred_first_name': 'Robert',
#      'preferred_name': 'Robert Thomas',
#      'user_id': 'user_00009Z2sSGIUDzcXctzkcD'}],
#    'payment_details': {'locale_uk': {'account_number': '16117989',
#      'sort_code': '040004'}},
#    'sort_code': '040004',
#    'type': 'uk_retail'}]}

# %%
def clean_account_details(response):
    owner = "The Account owner is {}. ".format(response['accounts'][0]['owners'][0]['preferred_name'])
    account_number = "Account number is {}. ".format(response['accounts'][0]['account_number'])
    sort_code = "Sort code is {}. ".format(response['accounts'][0]['sort_code'])
    currency  = "Currency is in {}. ".format(response['accounts'][0]['currency'])
    return [owner, account_number, sort_code, currency]

# %%
''.join(clean_account_details(response))
# Out:
# 'The Account owner is Robert Thomas. Account number is 16117989. Sort code is 040004. Currency is in GBP. '

# %%
accounts = [i for i in account_response['accounts'][0]]

# %%
account = ['owners','currency', 'account_number', 'sort_code']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-2039e36da884> in <module>()
# ----> 1 account = ['owners'['preferred_name'],'currency', 'account_number', 'sort_code']
#
# TypeError: string indices must be integers

# %%
#from tdm.lib.device import DddDevice, DeviceWHQuery


def perform():
    HEADERS = {"Authorization" : "Bearer eyJhbGciOiJFUzI1NiIsInR5cCI6IkpXVCJ9.eyJlYiI6IlFXUi93TER6QlVYZGs2Vk5iNTZ3IiwianRpIjoiYWNjdG9rXzAwMDA5b2E3bU81bFlla0wyTldlM3QiLCJ0eXAiOiJhdCIsInYiOiI2In0.nd2c5dnhCOrWgPMOycHsWMaIaHnpq6DUpmvo9QJ6fCTjPjrytKT8v09PripFNZFtBXTwHlRTxcdRUZ3Do-sgeA"}
    endpoint = "https://api.monzo.com/accounts"
    headers = HEADERS
    response = clean_account_details(requests.get(endpoint, headers=headers).json())
    return response

CURRENT = "user_00009Z2sSGIUDzcXctzkcD"
BALANCE = "balance"
TRANSACTIONS = "transactions"
POTS = "pots"

HEADERS = {"Authorization" : "Bearer eyJhbGciOiJFUzI1NiIsInR5cCI6IkpXVCJ9.eyJlYiI6IlFXUi93TER6QlVYZGs2Vk5iNTZ3IiwianRpIjoiYWNjdG9rXzAwMDA5b2E3bU81bFlla0wyTldlM3QiLCJ0eXAiOiJhdCIsInYiOiI2In0.nd2c5dnhCOrWgPMOycHsWMaIaHnpq6DUpmvo9QJ6fCTjPjrytKT8v09PripFNZFtBXTwHlRTxcdRUZ3Do-sgeA"}
ACCOUNT_ID = "user_00009Z2sSGIUDzcXctzkcD"
POT_ID = "pot_00009cj4TafFU2lqI95qR0"
API_ENDPOINTS = {BALANCE     : "https://api.monzo.com/balance",
                 #Shows the user their acount balance
                 ACCOUNTS    : "https://api.monzo.com/accounts",
                 #Shows the user account information
                 TRANSACTIONS : "https://api.monzo.com/transactions",
                 #Shows the user their transactions
                 POTS        : "https://api.monzo.com/pots"}
                 #Shows users pot


perform()
# Out:
# ['Robert Thomas', '16117989', '040004', 'GBP']

# %%
MonzoDevice.account_details.perform(self,"current")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-144-9b135c4aec6c> in <module>()
# ----> 1 MonzoDevice.account_details.perform(self,"current")
#
# NameError: name 'self' is not defined
